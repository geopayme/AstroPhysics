# %% [markdown]
# <a href="https://colab.research.google.com/github/geopayme/AstroPhysics/blob/main/Tensor_Validation_Lindgren_Sabine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🔬 Tensor Contraction Validation Notebook (SymPy + Colab)
#
# This notebook validates tensor notation used in Lindgren (2025), specifically focusing on:
# - Proper contraction rules
# - Invalid dummy index reuse
# - Confirmation of issues highlighted by Dr. Sabine Hossenfelder
#
# We use `sympy.tensor.tensor` to construct and analyze tensor expressions.

# %%
# 📦 Install necessary packages (SymPy should be preinstalled in Colab)
import sympy as sp
from sympy.tensor.tensor import TensorIndexType, tensor_indices, TensorHead

# %%
# ⚙️ Define basic index types and tensor symbols
Lorentz = TensorIndexType('Lorentz')
mu, nu = tensor_indices('mu nu', Lorentz)

A = TensorHead('A', [Lorentz])  # Electromagnetic potential
u = TensorHead('u', [Lorentz])  # Four-velocity

# %% [markdown]
# ## ✅ Example 1: Valid Contraction — \( A_\mu u^\mu \)
# This is a valid contraction of covariant and contravariant indices.

# %%
valid_expr = A(mu) * u(-mu)
valid_expr
# Out:
# A(L_0)*u(-L_0)

# %% [markdown]
# ## ❌ Example 2: Invalid Dummy Index Reuse — \( A_\mu A_\mu \)
# This incorrectly reuses the dummy index \( \mu \) twice in the same term.

# %%
# This will construct the expression, but logically it's invalid as both indices are summed
invalid_expr = A(mu) * A(mu)
invalid_expr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-72e5193b3fd5> in <cell line: 0>()
#       1 # This will construct the expression, but logically it's invalid as both indices are summed
# ----> 2 invalid_expr = A(mu) * A(mu)
#       3 invalid_expr
#
# /usr/local/lib/python3.11/dist-packages/sympy/tensor/tensor.py in __mul__(self, other)
#    2048         p(L_0)*q(-L_0)
#    2049         """
# -> 2050         return TensMul(self, other).doit()
#    2051
#    2052     def __rmul__(self, other):
#
# /usr/local/lib/python3.11/dist-packages/sympy/tensor/tensor.py in __new__(cls, *args, **kw_args)
#    3361         args = [i for arg in args for i in (arg.args if isinstance(arg, (TensMul, Mul)) else [arg])]
#    3362
# -> 3363         args, indices, free, dum = TensMul._tensMul_contract_indices(args, replace_indices=False)
#    3364
#    3365         # Data for indices:
#
# /usr/local/lib/python3.11/dist-packages/sympy/tensor/tensor.py in _tensMul_contract_indices(args, replace_indices)
#    3445
#    3446         args_indices = [get_indices(arg) for arg in args]
# -> 3447         indices, free, free_names, dummy_data = TensMul._indices_to_free_dum(args_indices)
#    3448
#    3449         cdt = defaultdict(int)
#
# /usr/local/lib/python3.11/dist-packages/sympy/tensor/tensor.py in _indices_to_free_dum(args_indices)
#    3421                     indices.append(index)
#    3422                 elif index in free2pos1:
# -> 3423                     raise ValueError("Repeated index: %s" % index)
#    3424                 else:
#    3425                     free2pos1[index] = pos1
#
# ValueError: Repeated index: mu

# %% [markdown]
# ## ❌ Example 3: Mixing Free and Contracted Indices
# This simulates the kind of mistake where an index is used both freely and in a sum.

# %%
# Simulate improper mixing: A^mu u_mu + B^mu
B = TensorHead('B', [Lorentz])
mixed_expr = A(mu) * u(-mu) + B(mu)
mixed_expr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-8805b275a3cf> in <cell line: 0>()
#       1 # Simulate improper mixing: A^mu u_mu + B^mu
#       2 B = TensorHead('B', [Lorentz])
# ----> 3 mixed_expr = A(mu) * u(-mu) + B(mu)
#       4 mixed_expr
#
# /usr/local/lib/python3.11/dist-packages/sympy/tensor/tensor.py in __add__(self, other)
#    2014
#    2015     def __add__(self, other):
# -> 2016         return TensAdd(self, other).doit()
#    2017
#    2018     def __radd__(self, other):
#
# /usr/local/lib/python3.11/dist-packages/sympy/tensor/tensor.py in doit(self, **hints)
#    2502
#    2503         # now check that all addends have the same indices:
# -> 2504         TensAdd._tensAdd_check(args)
#    2505
#    2506         # Collect terms appearing more than once, differing by their coefficients:
#
# /usr/local/lib/python3.11/dist-packages/sympy/tensor/tensor.py in _tensAdd_check(args)
#    2550         list_indices = [get_indices_set(arg) for arg in args[1:]]
#    2551         if not all(x == indices0 for x in list_indices):
# -> 2552             raise ValueError('all tensors must have the same indices')
#    2553
#    2554     @staticmethod
#
# ValueError: all tensors must have the same indices

# %% [markdown]
# ## ✅ Step-by-Step Validation Summary:
# - Expression 1 is valid (proper contraction).
# - Expression 2 is logically invalid: same dummy index used twice.
# - Expression 3 mixes free and contracted indices, which violates tensor rules.
#
# **Sabine’s critique of Lindgren (2025) is mathematically justified.**
